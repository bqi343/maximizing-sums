# %% [markdown]
# # Approximation Algorithms

# %% [markdown]
# [Arxiv Paper](https://arxiv.org/pdf/2205.15874.pdf)

# %%
from typing import Dict, List, Iterable
import numpy as np
import cvxpy as cp
from math import exp, log
import utils

# %% [markdown]
# ### Theorem 5.1 ($\ell \le 0$)

# %%
def r4(x):
    return round(x, 4)

def thm_ell_neg(betas: Iterable[float], csm: bool) -> List[float]:
    keys = ['f_OPT', 'f_z_and_OPT', 'f_z_or_OPT', 'L_OPT']
    linear_combs = []
    labels = []
    def add_linear_comb(d: Dict, label: str):
        val = [0] * len(keys)
        for k, v in d.items():
            val[keys.index(k)] = v
        linear_combs.append(val)
        labels.append(label)
    add_linear_comb({}, "nothing") # (0, 0, 0, 0)
    add_linear_comb({'f_z_and_OPT': 0.5, 'f_z_or_OPT': 0.5, 'L_OPT': 1}, "local_search_1") # (0, 0.5, 0.5, 1.0)
    add_linear_comb({'f_z_and_OPT': 1.0, 'L_OPT': 1}, "local_search_2")
    for t_f in np.linspace(0, 2, 41):
        for t_s in np.linspace(0, 2, 41):
            if t_s <= t_f:
                if csm:
                    if t_f > 1 + utils.EPS:
                        continue
                add_linear_comb(
                    {
                        'f_OPT': exp(t_s-t_f) + t_f * exp(t_s-t_f) - t_s * exp(t_s-t_f) - exp(-t_f),
                        'f_z_and_OPT': -exp(t_s-t_f) + exp(-t_f),
                        'f_z_or_OPT': -exp(t_s-t_f) - t_f * exp(t_s-t_f) + t_s * exp(t_s-t_f) + exp(-t_f) + t_f * exp(-t_f),
                        'L_OPT': t_f,
                    }, 
                    f'measured_{r4(t_s)}_{r4(t_f)}'
                )
    
    weights = cp.Variable(len(linear_combs), nonneg=True)
    sum_vars = []
    for j in range(len(keys)):
        sum_var = 0
        for i in range(len(linear_combs)):
            sum_var += linear_combs[i][j] * weights[i]
        sum_vars.append(sum_var)
    
    results = []
    for beta in betas:
        constraints = [sum(weights) == 1, sum_vars[1] >= 0, sum_vars[2] >= 0, sum_vars[3] <= beta]
        prob = cp.Problem(cp.Maximize(sum_vars[0]), constraints)
        result = prob.solve()
        print("beta =", beta, "result =", result)
        print("contributions:")
        for i in range(len(linear_combs)):
            if weights[i].value > utils.EPS:
                print(labels[i], weights[i].value)
        print()
        results.append(result)
    
    return results

# %%
ell_neg_usm = thm_ell_neg(np.linspace(0, 1.4, num=140+1), csm=False)
ell_neg_usm
# Out:
# beta = 0.0 result = 1.6935812991431703e-10
# contributions
# nothing 0.49999999978874404
# measured_0.0_0.0 0.49999999978874404
#
# beta = 0.01 result = 0.009512294693261026
# contributions
# nothing 0.40000000140706166
# measured_0.0_0.0 0.40000000140706166
# measured_0.0_0.05 0.19999999398080245
#
# beta = 0.02 result = 0.019024588505687858
# contributions
# nothing 0.3000000000619218
# measured_0.0_0.0 0.3000000000619218
# measured_0.0_0.05 0.39999999978119133
#
# beta = 0.03 result = 0.02853688342677501
# contributions
# nothing 0.20000000358980466
# measured_0.0_0.0 0.20000000358980466
# measured_0.0_0.05 0.599999987344917
#
# beta = 0.04 result = 0.038049177237314394
# contributions
# nothing 0.1000000000554776
# measured_0.0_0.0 0.1000000000554776
# measured_0.0_0.05 0.7999999986761047
#
# beta = 0.05 result = 0.04756147126436101
# contributions
# measured_0.0_0.05 0.9999999973252929
#
# beta = 0.06 result = 0.056145925350583784
# contributions
# measured_0.0_0.05 0.8000000001311447
# measured_0.0_0.1 0.1999999997382739
#
# beta = 0.07 result = 0.06473037976343975
# contributions
# measured_0.0_0.05 0.5999999983289552
# measured_0.0_0.1 0.39999999822234295
#
# beta = 0.08 result = 0.07331483386810714
# contributions
# measured_0.0_0.05 0.39999999845135964
# measured_0.0_0.1 0.5999999994018019
#
# beta = 0.09 result = 0.08189928769484933
# contributions
# measured_0.0_0.05 0.20000000016026695
# measured_0.0_0.1 0.7999999997344754
#
# beta = 0.1 result = 0.0904837419838457
# contributions
# measured_0.0_0.1 0.9999999929332547
#
# beta = 0.11 result = 0.09820823273992606
# contributions
# measured_0.0_0.1 0.7999999999420125
# measured_0.0_0.15 0.19999999995300793
#
# beta = 0.12 result = 0.10593272368803336
# contributions
# measured_0.0_0.1 0.600000000129171
# measured_0.0_0.15 0.39999999964851685
#
# beta = 0.13 result = 0.11365721465105828
# contributions
# measured_0.0_0.1 0.39999999894832455
# measured_0.0_0.15 0.5999999990653286
#
# beta = 0.14 result = 0.12138170558141603
# contributions
# measured_0.0_0.1 0.19999999951143257
# measured_0.0_0.15 0.7999999997892014
#
# beta = 0.15 result = 0.12910619648199806
# contributions
# measured_0.0_0.15 0.9999999986350208
#
# beta = 0.16 result = 0.1360341873083371
# contributions
# measured_0.0_0.15 0.8000000001226762
# measured_0.0_0.2 0.19999999963928455
#
# beta = 0.17 result = 0.1429621781339049
# contributions
# measured_0.0_0.15 0.6000000000424938
# measured_0.0_0.2 0.39999999982227535
#
# beta = 0.18 result = 0.14989016906481892
# contributions
# measured_0.0_0.15 0.40000000034872796
# measured_0.0_0.2 0.5999999982199486
#
# beta = 0.19 result = 0.15681815980361258
# contributions
# measured_0.0_0.15 0.20000000005961585
# measured_0.0_0.2 0.7999999995783179
#
# beta = 0.2 result = 0.1637461506586881
# contributions
# measured_0.0_0.2 0.9999999965250759
#
# beta = 0.21 result = 0.16993695966927913
# contributions
# measured_0.0_0.2 0.7999999999320089
# measured_0.0_0.25 0.19999999974828284
#
# beta = 0.22 result = 0.1761277687004397
# contributions
# measured_0.0_0.2 0.5999999999297876
# measured_0.0_0.25 0.39999999965411787
#
# beta = 0.23 result = 0.1823185777101439
# contributions
# measured_0.0_0.2 0.39999999988563306
# measured_0.0_0.25 0.6000000000015832
#
# beta = 0.24 result = 0.18850938685300678
# contributions
# measured_0.0_0.2 0.19999999726037596
# measured_0.0_0.25 0.7999999992580461
#
# beta = 0.25 result = 0.19470019585273843
# contributions
# measured_0.0_0.25 0.9999999969991954
#
# beta = 0.26 result = 0.20020924987436964
# contributions
# measured_0.0_0.25 0.7999999996337216
# measured_0.0_0.3 0.19999999983020028
#
# beta = 0.27 result = 0.20571830395563243
# contributions
# measured_0.0_0.25 0.5999999997976523
# measured_0.0_0.3 0.39999999974065426
#
# beta = 0.28 result = 0.2112273580348474
# contributions
# measured_0.0_0.25 0.39999999997965857
# measured_0.0_0.3 0.5999999999301314
#
# beta = 0.29 result = 0.2167364121618734
# contributions
# measured_0.0_0.25 0.1999999992717992
# measured_0.0_0.3 0.7999999998276841
#
# beta = 0.3 result = 0.22224546622123179
# contributions
# measured_0.0_0.3 0.9999999994668675
#
# beta = 0.31 result = 0.2271245392461987
# contributions
# measured_0.0_0.3 0.7999999999904399
# measured_0.0_0.35 0.19999999994800474
#
# beta = 0.32 result = 0.2320036124748374
# contributions
# measured_0.0_0.3 0.5999999879044263
# measured_0.0_0.35 0.40000000172539635
#
# beta = 0.33 result = 0.23688268532676474
# contributions
# measured_0.0_0.3 0.3999999997843772
# measured_0.0_0.35 0.5999999999582109
#
# beta = 0.34 result = 0.24176175845216308
# contributions
# measured_0.0_0.3 0.20000000011116686
# measured_0.0_0.35 0.7999999978467939
#
# beta = 0.35000000000000003 result = 0.24664083140494636
# contributions
# measured_0.0_0.35 0.9999999999024117
#
# beta = 0.36 result = 0.2509382689011808
# contributions
# measured_0.0_0.35 0.799999999252109
# measured_0.0_0.4 0.19999999858175904
#
# beta = 0.37 result = 0.2552357062459843
# contributions
# measured_0.0_0.35 0.5999999997894859
# measured_0.0_0.4 0.399999999668424
#
# beta = 0.38 result = 0.2595331436336315
# contributions
# measured_0.0_0.35 0.39999999935959635
# measured_0.0_0.4 0.5999999999698027
#
# beta = 0.39 result = 0.2638305811632357
# contributions
# measured_0.0_0.35 0.1999999914719588
# measured_0.0_0.4 0.80000000284218
#
# beta = 0.4 result = 0.2681280184367834
# contributions
# measured_0.0_0.4 0.9999999995011385
#
# beta = 0.41000000000000003 result = 0.27188894837949296
# contributions
# measured_0.0_0.4 0.7999999999235842
# measured_0.0_0.45 0.2000000000046736
#
# beta = 0.42 result = 0.2756498783924005
# contributions
# measured_0.0_0.4 0.5999999976606452
# measured_0.0_0.45 0.4000000004020698
#
# beta = 0.43 result = 0.2794108083234606
# contributions
# measured_0.0_0.4 0.39999999929327745
# measured_0.0_0.45 0.6000000001254234
#
# beta = 0.44 result = 0.2831717382941946
# contributions
# measured_0.0_0.4 0.1999999997081411
# measured_0.0_0.45 0.7999999999641848
#
# beta = 0.45 result = 0.28693266823204266
# contributions
# measured_0.0_0.45 0.999999999961381
#
# beta = 0.46 result = 0.29019920068532573
# contributions
# measured_0.0_0.45 0.7999999994328254
# measured_0.0_0.5 0.1999999982274306
#
# beta = 0.47000000000000003 result = 0.29346573295745676
# contributions
# measured_0.0_0.45 0.5999999994764856
# measured_0.0_0.5 0.3999999997038907
#
# beta = 0.48 result = 0.29673226522186485
# contributions
# measured_0.0_0.45 0.39999999964276334
# measured_0.0_0.5 0.6000000001121644
#
# beta = 0.49 result = 0.29999879755713516
# contributions
# measured_0.0_0.45 0.19999999945124333
# measured_0.0_0.5 0.8000000000954592
#
# beta = 0.5 result = 0.3032653299208483
# contributions
# measured_0.0_0.5 0.9999999974123329
#
# beta = 0.51 result = 0.3060767430296111
# contributions
# measured_0.0_0.5 0.7999999999552958
# measured_0.0_0.55 0.19999999998043874
#
# beta = 0.52 result = 0.3088881562781987
# contributions
# measured_0.0_0.5 0.5999999978295737
# measured_0.0_0.55 0.39999999959637844
#
# beta = 0.53 result = 0.311699569369419
# contributions
# measured_0.0_0.5 0.39999999999482194
# measured_0.0_0.55 0.5999999999917119
#
# beta = 0.54 result = 0.3145109825466697
# contributions
# measured_0.0_0.5 0.19999999987559114
# measured_0.0_0.55 0.800000000028766
#
# beta = 0.55 result = 0.3173223957105257
# contributions
# measured_0.0_0.55 0.9999999999146727
#
# beta = 0.56 result = 0.3197153129229596
# contributions
# measured_0.0_0.55 0.8000000002478045
# measured_0.0_0.6 0.19999999932277157
#
# beta = 0.5700000000000001 result = 0.32210823010502093
# contributions
# measured_0.0_0.55 0.6000000001740328
# measured_0.0_0.6 0.39999999955890925
#
# beta = 0.58 result = 0.32450114727983614
# contributions
# measured_0.0_0.55 0.3999999999987666
# measured_0.0_0.6 0.5999999999759029
#
# beta = 0.59 result = 0.32689406446800884
# contributions
# measured_0.0_0.55 0.19999999999373758
# measured_0.0_0.6 0.7999999999917277
#
# beta = 0.6 result = 0.329286981661829
# contributions
# measured_0.0_0.6 0.999999999892838
#
# beta = 0.61 result = 0.33129553632095593
# contributions
# measured_0.0_0.6 0.8000000000869893
# measured_0.0_0.65 0.1999999995541568
#
# beta = 0.62 result = 0.3333040909529538
# contributions
# measured_0.0_0.6 0.5999999999853053
# measured_0.0_0.65 0.39999999999622476
#
# beta = 0.63 result = 0.33531264560470003
# contributions
# measured_0.0_0.6 0.39999999982158
# measured_0.0_0.65 0.6000000001018715
#
# beta = 0.64 result = 0.33732120028160956
# contributions
# measured_0.0_0.6 0.20000000027702272
# measured_0.0_0.65 0.7999999989649169
#
# beta = 0.65 result = 0.33932975492468903
# contributions
# measured_0.0_0.65 0.9999999991301471
#
# beta = 0.66 result = 0.34102266637814677
# contributions
# local_search_1 0.00529247235515727
# local_search_2 0.0012753240252119625
# measured_0.0_0.65 0.8394067784287994
# measured_0.05_0.7 0.15402542432905417
#
# beta = 0.67 result = 0.34271557781897444
# contributions
# local_search_1 0.010584944672095023
# local_search_2 0.002550648037350825
# measured_0.0_0.65 0.6788135563931312
# measured_0.05_0.7 0.3080508505422951
#
# beta = 0.68 result = 0.34440848927925943
# contributions
# local_search_1 0.015877417006262027
# local_search_2 0.0038259720556871467
# measured_0.0_0.65 0.5182203344958772
# measured_0.05_0.7 0.46207627593231193
#
# beta = 0.6900000000000001 result = 0.3461014007367732
# contributions
# local_search_1 0.021169889308263492
# local_search_2 0.0051012960669834535
# measured_0.0_0.65 0.3576271119228327
# measured_0.05_0.7 0.6161017012083755
#
# beta = 0.7000000000000001 result = 0.34779431219738954
# contributions
# local_search_1 0.02646236165640968
# local_search_2 0.006376620088423308
# measured_0.0_0.65 0.19703389010022457
# measured_0.05_0.7 0.7701271269985079
#
# beta = 0.71 result = 0.34948722364421614
# contributions
# local_search_1 0.031754833997525926
# local_search_2 0.007651944104798592
# measured_0.0_0.65 0.036440668612439844
# measured_0.05_0.7 0.9241525532362228
#
# beta = 0.72 result = 0.35106851106610054
# contributions
# local_search_1 0.037160364109320325
# local_search_2 0.008730817529881429
# measured_0.05_0.7 0.829455907739468
# measured_0.1_0.75 0.12465290978809085
#
# beta = 0.73 result = 0.3526170351336859
# contributions
# local_search_1 0.04259907840453471
# local_search_2 0.009752029711270432
# measured_0.05_0.7 0.6617555401511991
# measured_0.1_0.75 0.28589335078625133
#
# beta = 0.74 result = 0.3541655592152732
# contributions
# local_search_1 0.04803779270711226
# local_search_2 0.01077324189725816
# measured_0.05_0.7 0.49405517156084033
# measured_0.1_0.75 0.44713379150658644
#
# beta = 0.75 result = 0.35571408323505443
# contributions
# local_search_1 0.05347650697355261
# local_search_2 0.011794454060515503
# measured_0.05_0.7 0.32635480497416647
# measured_0.1_0.75 0.608374233772631
#
# beta = 0.76 result = 0.3572626072914963
# contributions
# local_search_1 0.058915221262022456
# local_search_2 0.012815666237376537
# measured_0.05_0.7 0.1586544373282794
# measured_0.1_0.75 0.7696146749755285
#
# beta = 0.77 result = 0.3588035797848804
# contributions
# local_search_1 0.06436082767794558
# local_search_2 0.013823772145163915
# measured_0.1_0.75 0.9127383992169484
# measured_0.15_0.8 0.009077000854216411
#
# beta = 0.78 result = 0.3602121072145713
# contributions
# local_search_1 0.06992731349294733
# local_search_2 0.014602010295671592
# measured_0.1_0.75 0.7381172950865155
# measured_0.15_0.8 0.1773533810339305
#
# beta = 0.79 result = 0.3616206346450883
# contributions
# local_search_1 0.07549379930864739
# local_search_2 0.015380248446479141
# measured_0.1_0.75 0.5634961910045448
# measured_0.15_0.8 0.34562976117667205
#
# beta = 0.8 result = 0.36302916207432995
# contributions
# local_search_1 0.08106028512288327
# local_search_2 0.016158486596727806
# measured_0.1_0.75 0.38887508686687067
# measured_0.15_0.8 0.5139061413899368
#
# beta = 0.81 result = 0.36443768950571875
# contributions
# local_search_1 0.08662677094152292
# local_search_2 0.016936724748750322
# measured_0.1_0.75 0.21425398256381473
# measured_0.15_0.8 0.6821825215002145
#
# beta = 0.8200000000000001 result = 0.3658462169347735
# contributions
# local_search_1 0.09219325675407833
# local_search_2 0.0177149628981965
# measured_0.1_0.75 0.039632878594933835
# measured_0.15_0.8 0.8504589016606925
#
# beta = 0.8300000000000001 result = 0.3671502269855766
# contributions
# local_search_1 0.0978441021231425
# local_search_2 0.018314486393046937
# measured_0.15_0.8 0.7484757654187544
# measured_0.2_0.85 0.1353656456154159
#
# beta = 0.84 result = 0.36842355047435016
# contributions
# local_search_1 0.10351971569272055
# local_search_2 0.01886153883002599
# measured_0.15_0.8 0.5671437620302014
# measured_0.2_0.85 0.3104749813644998
#
# beta = 0.85 result = 0.3696968739571791
# contributions
# local_search_1 0.10919532924604196
# local_search_2 0.019408591261230238
# measured_0.15_0.8 0.38581176002938283
# measured_0.2_0.85 0.4855843164456383
#
# beta = 0.86 result = 0.3709701974074439
# contributions
# local_search_1 0.11487094271439921
# local_search_2 0.019955643664522595
# measured_0.15_0.8 0.2044797591128153
# measured_0.2_0.85 0.6606936544578237
#
# beta = 0.87 result = 0.3722435208976867
# contributions
# local_search_1 0.12054655626111394
# local_search_2 0.020502696093165657
# measured_0.15_0.8 0.023147757021043137
# measured_0.2_0.85 0.8358029898235664
#
# beta = 0.88 result = 0.37340338635045134
# contributions
# local_search_1 0.12630110815560006
# local_search_2 0.020858819596247653
# measured_0.2_0.85 0.694319853347177
# measured_0.25_0.9 0.15852021564832358
#
# beta = 0.89 result = 0.3745466489892939
# contributions
# local_search_1 0.13206721132579838
# local_search_2 0.021187003641748046
# measured_0.2_0.85 0.5065084286305395
# measured_0.25_0.9 0.3402373546363686
#
# beta = 0.9 result = 0.37568991163880067
# contributions
# local_search_1 0.13783331448925898
# local_search_2 0.021515187685122898
# measured_0.2_0.85 0.31869700432821546
# measured_0.25_0.9 0.5219544934495365
#
# beta = 0.91 result = 0.3768331742952566
# contributions
# local_search_1 0.1435994176924889
# local_search_2 0.021843371742151594
# measured_0.2_0.85 0.13088557886048166
# measured_0.25_0.9 0.7036716316759531
#
# beta = 0.92 result = 0.3779386644080668
# contributions
# local_search_1 0.1493873526156049
# local_search_2 0.02210907342118549
# measured_0.25_0.9 0.7714964245602554
# measured_0.3_0.95 0.05700714631293599
#
# beta = 0.93 result = 0.3789573066890315
# contributions
# local_search_1 0.1552254834087816
# local_search_2 0.02223111369402097
# measured_0.25_0.9 0.577456596499122
# measured_0.3_0.95 0.24508680556426013
#
# beta = 0.9400000000000001 result = 0.37997594898677783
# contributions
# local_search_1 0.1610636142304898
# local_search_2 0.022353153975869237
# measured_0.25_0.9 0.38341676817814646
# measured_0.3_0.95 0.43316646352918664
#
# beta = 0.9500000000000001 result = 0.3809945912981977
# contributions
# local_search_1 0.16690174511027644
# local_search_2 0.02247519427753385
# measured_0.25_0.9 0.18937693827907115
# measured_0.3_0.95 0.6212461203437689
#
# beta = 0.96 result = 0.38201037547110306
# contributions
# local_search_1 0.17274117121641627
# local_search_2 0.022592593480932704
# measured_0.3_0.95 0.7999999989839485
# measured_0.35_1.0 0.004666234533360081
#
# beta = 0.97 result = 0.3829100811162015
# contributions
# local_search_1 0.17863320275269545
# local_search_2 0.022521501256628572
# measured_0.3_0.95 0.5999999995169386
# measured_0.35_1.0 0.19884529576704404
#
# beta = 0.98 result = 0.3838097867591898
# contributions
# local_search_1 0.18452523430209372
# local_search_2 0.022450409037366763
# measured_0.3_0.95 0.39999999997287483
# measured_0.35_1.0 0.39302435659965884
#
# beta = 0.99 result = 0.38470949241933056
# contributions
# local_search_1 0.1904172659190529
# local_search_2 0.022379316840970182
# measured_0.3_0.95 0.19999999864856458
# measured_0.35_1.0 0.5872034158901521
#
# beta = 1.0 result = 0.3856091980491218
# contributions
# local_search_1 0.19630929743257147
# local_search_2 0.02230822460989123
# measured_0.35_1.0 0.7813824776970155
#
# beta = 1.01 result = 0.38639583971885644
# contributions
# local_search_1 0.2022375838921366
# local_search_2 0.022057180222689998
# measured_0.35_1.0 0.5757052344197018
# measured_0.4_1.05 0.1999999997772154
#
# beta = 1.02 result = 0.3871824813854263
# contributions
# local_search_1 0.20816587027993042
# local_search_2 0.021806135809572927
# measured_0.35_1.0 0.3700279938628103
# measured_0.4_1.05 0.3999999998860939
#
# beta = 1.03 result = 0.3879691230523858
# contributions
# local_search_1 0.2140941567029313
# local_search_2 0.021555091409310275
# measured_0.35_1.0 0.16435075187335332
# measured_0.4_1.05 0.5999999999662375
#
# beta = 1.04 result = 0.38873425409779355
# contributions
# local_search_1 0.22002630519184574
# local_search_2 0.021270548995042424
# measured_0.4_1.05 0.717406291623764
# measured_0.45_1.1 0.04129685415813088
#
# beta = 1.05 result = 0.3894138398450444
# contributions
# local_search_1 0.22597381267475086
# local_search_2 0.020852788787465958
# measured_0.4_1.05 0.5063467969570755
# measured_0.45_1.1 0.24682660140163845
#
# beta = 1.06 result = 0.39009342558942406
# contributions
# local_search_1 0.23192132015649947
# local_search_2 0.02043502857976886
# measured_0.4_1.05 0.2952873024417803
# measured_0.45_1.1 0.4523563486916229
#
# beta = 1.07 result = 0.3907730113349987
# contributions
# local_search_1 0.2378688276388659
# local_search_2 0.02001726837215595
# measured_0.4_1.05 0.08422780792951544
# measured_0.45_1.1 0.6578860958908708
#
# beta = 1.08 result = 0.3913919245585856
# contributions
# local_search_1 0.24381808625897833
# local_search_2 0.01950724749124121
# measured_0.45_1.1 0.6100239986785225
# measured_0.5_1.15 0.12665066738938324
#
# beta = 1.09 result = 0.3919705457054491
# contributions
# local_search_1 0.24976850781924645
# local_search_2 0.018935957116758315
# measured_0.45_1.1 0.39388660445892165
# measured_0.5_1.15 0.33740892910510667
#
# beta = 1.1 result = 0.39254916681985663
# contributions
# local_search_1 0.2557189293418114
# local_search_2 0.018364666730249234
# measured_0.45_1.1 0.17774921174112404
# measured_0.5_1.15 0.5481671920710618
#
# beta = 1.11 result = 0.39311094342256914
# contributions
# local_search_1 0.2616671185807621
# local_search_2 0.017768423105611914
# measured_0.5_1.15 0.6822578332300158
# measured_0.55_1.2 0.038306624974984375
#
# beta = 1.12 result = 0.39359472462145384
# contributions
# local_search_1 0.2676049715795602
# local_search_2 0.017056638210362973
# measured_0.5_1.15 0.46135356060649446
# measured_0.55_1.2 0.25398482922119037
#
# beta = 1.1300000000000001 result = 0.3940785058185787
# contributions
# local_search_1 0.27354282457709084
# local_search_2 0.01634485331490567
# measured_0.5_1.15 0.24044928841190563
# measured_0.55_1.2 0.4696630332386877
#
# beta = 1.1400000000000001 result = 0.39456228701605456
# contributions
# local_search_1 0.27948067757286027
# local_search_2 0.015633068418712398
# measured_0.5_1.15 0.019545016212945257
# measured_0.55_1.2 0.6853412371273765
#
# beta = 1.1500000000000001 result = 0.39496518983952317
# contributions
# local_search_1 0.2853937856574742
# local_search_2 0.014804882653679378
# measured_0.55_1.2 0.4990066584387682
# measured_0.6_1.25 0.20079467323212166
#
# beta = 1.16 result = 0.3953602421945075
# contributions
# local_search_1 0.2913044918674194
# local_search_2 0.013965398393008
# measured_0.55_1.2 0.27365054755425167
# measured_0.6_1.25 0.4210795606435946
#
# beta = 1.17 result = 0.39575529452505287
# contributions
# local_search_1 0.29721519807757574
# local_search_2 0.013125914131074017
# measured_0.55_1.2 0.048294438938762174
# measured_0.6_1.25 0.6413644487996916
#
# beta = 1.18 result = 0.3960853894851159
# contributions
# local_search_1 0.3030938805744848
# local_search_2 0.012195897374228139
# measured_0.6_1.25 0.5082613323239564
# measured_0.65_1.3 0.17644888962333255
#
# beta = 1.19 result = 0.39639776699889806
# contributions
# local_search_1 0.3089638284480982
# local_search_2 0.011241187435735038
# measured_0.6_1.25 0.27876990466424195
# measured_0.65_1.3 0.40102507939857124
#
# beta = 1.2 result = 0.39671014451943315
# contributions
# local_search_1 0.3148337763218849
# local_search_2 0.010286477497710462
# measured_0.6_1.25 0.04927847692357928
# measured_0.65_1.3 0.6256012687021161
#
# beta = 1.21 result = 0.3969622781007628
# contributions
# local_search_1 0.3206618236450214
# local_search_2 0.009250771388399267
# measured_0.65_1.3 0.4906118345090209
# measured_0.7_1.35 0.1794755701178681
#
# beta = 1.22 result = 0.39719793823074595
# contributions
# local_search_1 0.32647841344348133
# local_search_2 0.008192917216485301
# measured_0.65_1.3 0.257300685409413
# measured_0.7_1.35 0.4080279838838621
#
# beta = 1.23 result = 0.3974335983635483
# contributions
# local_search_1 0.3322950032409477
# local_search_2 0.007135063044532957
# measured_0.65_1.3 0.023989536007081733
# measured_0.7_1.35 0.6365803976872445
#
# beta = 1.24 result = 0.3976056559854312
# contributions
# local_search_1 0.33805335063101793
# local_search_2 0.005995103326180823
# measured_0.7_1.35 0.44761236828577877
# measured_0.75_1.4 0.20833917763712143
#
# beta = 1.25 result = 0.39777042436931354
# contributions
# local_search_1 0.3438050230865824
# local_search_2 0.004845733810633935
# measured_0.7_1.35 0.21079394481988134
# measured_0.75_1.4 0.44055529814407884
#
# beta = 1.26 result = 0.3979280246359689
# contributions
# local_search_1 0.3495484071638844
# local_search_2 0.0036875301983983894
# measured_0.75_1.4 0.6208765636409385
# measured_0.8_1.45 0.025887498611222148
#
# beta = 1.27 result = 0.39802756432056235
# contributions
# local_search_1 0.3552246567969485
# local_search_2 0.0024577718800290705
# measured_0.75_1.4 0.38085814189525646
# measured_0.8_1.45 0.26145942939654504
#
# beta = 1.28 result = 0.39812710400994794
# contributions
# local_search_1 0.3609009064230562
# local_search_2 0.0012280135608207267
# measured_0.75_1.4 0.14083972016783047
# measured_0.8_1.45 0.4970313597672939
#
# beta = 1.29 result = 0.39820101596527774
# contributions
# local_search_1 0.36641047635918267
# measured_0.8_1.45 0.5406027768699205
# measured_0.85_1.5 0.09298674534922531
#
# beta = 1.3 result = 0.39820101594947527
# contributions
# local_search_1 0.36641047639729346
# measured_0.8_1.45 0.5406027761346731
# measured_0.85_1.5 0.09298674715631895
#
# beta = 1.31 result = 0.39820101594853197
# contributions
# local_search_1 0.36641047640022445
# measured_0.8_1.45 0.540602776118595
# measured_0.85_1.5 0.09298674718895739
#
# beta = 1.32 result = 0.39820101594908114
# contributions
# local_search_1 0.3664104763953584
# measured_0.8_1.45 0.5406027763008362
# measured_0.85_1.5 0.09298674711731489
#
# beta = 1.33 result = 0.3982010159629967
# contributions
# local_search_1 0.3664104764210688
# measured_0.8_1.45 0.540602775441111
# measured_0.85_1.5 0.09298674603933235
#
# beta = 1.34 result = 0.398201015959116
# contributions
# local_search_1 0.3664104763980327
# measured_0.8_1.45 0.5406027761063292
# measured_0.85_1.5 0.09298674642868142
#
# beta = 1.35 result = 0.3982010159504843
# contributions
# local_search_1 0.36641047640775426
# measured_0.8_1.45 0.5406027756188276
# measured_0.85_1.5 0.09298674751173346
#
# beta = 1.36 result = 0.39820101594726776
# contributions
# local_search_1 0.36641047639865715
# measured_0.8_1.45 0.5406027761891888
# measured_0.85_1.5 0.09298674736855263
#
# beta = 1.37 result = 0.3982010159474121
# contributions
# local_search_1 0.3664104763985566
# measured_0.8_1.45 0.5406027761873875
# measured_0.85_1.5 0.09298674737186652
#
# beta = 1.3800000000000001 result = 0.398201015953414
# contributions
# local_search_1 0.36641047639735835
# measured_0.8_1.45 0.5406027756924439
# measured_0.85_1.5 0.09298674704527468
#
# beta = 1.3900000000000001 result = 0.39820101594714974
# contributions
# local_search_1 0.3664104763987283
# measured_0.8_1.45 0.540602776183531
# measured_0.85_1.5 0.09298674736675008
#
# beta = 1.4 result = 0.3982010159473649
# contributions
# local_search_1 0.36641047639829605
# measured_0.8_1.45 0.5406027761929336
# measured_0.85_1.5 0.09298674734824224
# [1.6935812991431703e-10,
#  0.009512294693261026,
#  0.019024588505687858,
#  0.02853688342677501,
#  0.038049177237314394,
#  0.04756147126436101,
#  0.056145925350583784,
#  0.06473037976343975,
#  0.07331483386810714,
#  0.08189928769484933,
#  0.0904837419838457,
#  0.09820823273992606,
#  0.10593272368803336,
#  0.11365721465105828,
#  0.12138170558141603,
#  0.12910619648199806,
#  0.1360341873083371,
#  0.1429621781339049,
#  0.14989016906481892,
#  0.15681815980361258,
#  0.1637461506586881,
#  0.16993695966927913,
#  0.1761277687004397,
#  0.1823185777101439,
#  0.18850938685300678,
#  0.19470019585273843,
#  0.20020924987436964,
#  0.20571830395563243,
#  0.2112273580348474,
#  0.2167364121618734,
#  0.22224546622123179,
#  0.2271245392461987,
#  0.2320036124748374,
#  0.23688268532676474,
#  0.24176175845216308,
#  0.24664083140494636,
#  0.2509382689011808,
#  0.2552357062459843,
#  0.2595331436336315,
#  0.2638305811632357,
#  0.2681280184367834,
#  0.27188894837949296,
#  0.2756498783924005,
#  0.2794108083234606,
#  0.2831717382941946,
#  0.28693266823204266,
#  0.29019920068532573,
#  0.29346573295745676,
#  0.29673226522186485,
#  0.29999879755713516,
#  0.3032653299208483,
#  0.3060767430296111,
#  0.3088881562781987,
#  0.311699569369419,
#  0.3145109825466697,
#  0.3173223957105257,
#  0.3197153129229596,
#  0.32210823010502093,
#  0.32450114727983614,
#  0.32689406446800884,
#  0.329286981661829,
#  0.33129553632095593,
#  0.3333040909529538,
#  0.33531264560470003,
#  0.33732120028160956,
#  0.33932975492468903,
#  0.34102266637814677,
#  0.34271557781897444,
#  0.34440848927925943,
#  0.3461014007367732,
#  0.34779431219738954,
#  0.34948722364421614,
#  0.35106851106610054,
#  0.3526170351336859,
#  0.3541655592152732,
#  0.35571408323505443,
#  0.3572626072914963,
#  0.3588035797848804,
#  0.3602121072145713,
#  0.3616206346450883,
#  0.36302916207432995,
#  0.36443768950571875,
#  0.3658462169347735,
#  0.3671502269855766,
#  0.36842355047435016,
#  0.3696968739571791,
#  0.3709701974074439,
#  0.3722435208976867,
#  0.37340338635045134,
#  0.3745466489892939,
#  0.37568991163880067,
#  0.3768331742952566,
#  0.3779386644080668,
#  0.3789573066890315,
#  0.37997594898677783,
#  0.3809945912981977,
#  0.38201037547110306,
#  0.3829100811162015,
#  0.3838097867591898,
#  0.38470949241933056,
#  0.3856091980491218,
#  0.38639583971885644,
#  0.3871824813854263,
#  0.3879691230523858,
#  0.38873425409779355,
#  0.3894138398450444,
#  0.39009342558942406,
#  0.3907730113349987,
#  0.3913919245585856,
#  0.3919705457054491,
#  0.39254916681985663,
#  0.39311094342256914,
#  0.39359472462145384,
#  0.3940785058185787,
#  0.39456228701605456,
#  0.39496518983952317,
#  0.3953602421945075,
#  0.39575529452505287,
#  0.3960853894851159,
#  0.39639776699889806,
#  0.39671014451943315,
#  0.3969622781007628,
#  0.39719793823074595,
#  0.3974335983635483,
#  0.3976056559854312,
#  0.39777042436931354,
#  0.3979280246359689,
#  0.39802756432056235,
#  0.39812710400994794,
#  0.39820101596527774,
#  0.39820101594947527,
#  0.39820101594853197,
#  0.39820101594908114,
#  0.3982010159629967,
#  0.398201015959116,
#  0.3982010159504843,
#  0.39820101594726776,
#  0.3982010159474121,
#  0.398201015953414,
#  0.39820101594714974,
#  0.3982010159473649]

# %% [markdown]
# ## Section 5 Table 1 ($\ell \le 0$)

# %%
table = []
for i in range(5, 141):
    if i%10 == 0:
        table.append([round(0.01*i, 2), round(ell_neg_usm[i], 4)])
for i in range(7):
    print(table[i][0], '&', table[i][1], '&', table[i+7][0], '&', table[i+7][1], '\\\\')
# Out:
# 0.1 & 0.0905 & 0.8 & 0.363 \\
# 0.2 & 0.1637 & 0.9 & 0.3757 \\
# 0.3 & 0.2222 & 1.0 & 0.3856 \\
# 0.4 & 0.2681 & 1.1 & 0.3925 \\
# 0.5 & 0.3033 & 1.2 & 0.3967 \\
# 0.6 & 0.3293 & 1.3 & 0.3982 \\
# 0.7 & 0.3478 & 1.4 & 0.3982 \\

# %%
def gen_lu_et_al():
    for beta in np.linspace(0, 1.4, 15):
        print(round(beta, 4), round(beta*exp(-beta), 4))

gen_lu_et_al()
# Out:
# 0.0 0.0
# 0.1 0.0905
# 0.2 0.1637
# 0.3 0.2222
# 0.4 0.2681
# 0.5 0.3033
# 0.6 0.3293
# 0.7 0.3476
# 0.8 0.3595
# 0.9 0.3659
# 1.0 0.3679
# 1.1 0.3662
# 1.2 0.3614
# 1.3 0.3543
# 1.4 0.3452

# %%
ell_neg_csm = thm_ell_neg(np.linspace(0, 1.0, num=100+1), csm=True)
ell_neg_csm
# Out:
# beta = 0.0 result = 1.0180590221663363e-11
# contributions:
# nothing 0.4999999999776724
# measured_0.0_0.0 0.4999999999776724
#
# beta = 0.01 result = 0.009512294334414428
# contributions:
# nothing 0.40000000056960633
# measured_0.0_0.0 0.40000000056960633
# measured_0.0_0.05 0.19999999688429823
#
# beta = 0.02 result = 0.019024588585388715
# contributions:
# nothing 0.30000000034511337
# measured_0.0_0.0 0.30000000034511337
# measured_0.0_0.05 0.3999999978526211
#
# beta = 0.03 result = 0.028536882746117678
# contributions:
# nothing 0.20000000001378254
# measured_0.0_0.0 0.20000000001378254
# measured_0.0_0.05 0.5999999999135974
#
# beta = 0.04 result = 0.03804917704862066
# contributions:
# nothing 0.10000000027141356
# measured_0.0_0.0 0.10000000027141356
# measured_0.0_0.05 0.7999999987231936
#
# beta = 0.05 result = 0.047561471230423084
# contributions:
# measured_0.0_0.05 0.9999999996722824
#
# beta = 0.06 result = 0.05614592539364061
# contributions:
# measured_0.0_0.05 0.7999999986509418
# measured_0.0_0.1 0.1999999990858268
#
# beta = 0.07 result = 0.06473037947879183
# contributions:
# measured_0.0_0.05 0.5999999988842019
# measured_0.0_0.1 0.3999999998472386
#
# beta = 0.08 result = 0.07331483359597894
# contributions:
# measured_0.0_0.05 0.39999999910338846
# measured_0.0_0.1 0.600000000053558
#
# beta = 0.09 result = 0.08189928769216523
# contributions:
# measured_0.0_0.05 0.1999999998190732
# measured_0.0_0.1 0.8000000000048301
#
# beta = 0.1 result = 0.09048374180975695
# contributions:
# measured_0.0_0.1 0.999999999799034
#
# beta = 0.11 result = 0.09820823278175068
# contributions:
# measured_0.0_0.1 0.799999999131143
# measured_0.0_0.15 0.20000000002499874
#
# beta = 0.12 result = 0.10593272371064946
# contributions:
# measured_0.0_0.1 0.5999999996290466
# measured_0.0_0.15 0.3999999996363201
#
# beta = 0.13 result = 0.11365721460686672
# contributions:
# measured_0.0_0.1 0.3999999999845728
# measured_0.0_0.15 0.5999999999298893
#
# beta = 0.14 result = 0.12138170553611831
# contributions:
# measured_0.0_0.1 0.20000000001868276
# measured_0.0_0.15 0.7999999999036579
#
# beta = 0.15 result = 0.12910619651169156
# contributions:
# measured_0.0_0.15 0.9999999990170273
#
# beta = 0.16 result = 0.13603418729582684
# contributions:
# measured_0.0_0.15 0.7999999999788496
# measured_0.0_0.2 0.1999999999933758
#
# beta = 0.17 result = 0.1429621781285223
# contributions:
# measured_0.0_0.15 0.599999999948104
# measured_0.0_0.2 0.39999999997325986
#
# beta = 0.18 result = 0.1498901690474302
# contributions:
# measured_0.0_0.15 0.3999999993439785
# measured_0.0_0.2 0.5999999996322508
#
# beta = 0.19 result = 0.15681815984555666
# contributions:
# measured_0.0_0.15 0.1999999991236871
# measured_0.0_0.2 0.7999999995930439
#
# beta = 0.2 result = 0.16374615061955003
# contributions:
# measured_0.0_0.2 0.999999999602524
#
# beta = 0.21 result = 0.16993695971503958
# contributions:
# measured_0.0_0.2 0.7999999996522014
# measured_0.0_0.25 0.19999999942616786
#
# beta = 0.22 result = 0.17612776869664612
# contributions:
# measured_0.0_0.2 0.5999999998230165
# measured_0.0_0.25 0.3999999997231423
#
# beta = 0.23 result = 0.18231857771072768
# contributions:
# measured_0.0_0.2 0.3999999999538629
# measured_0.0_0.25 0.6000000000081464
#
# beta = 0.24 result = 0.18850938682347984
# contributions:
# measured_0.0_0.2 0.19999999896021423
# measured_0.0_0.25 0.8000000000095953
#
# beta = 0.25 result = 0.1947001957951922
# contributions:
# measured_0.0_0.25 0.9999999994447609
#
# beta = 0.26 result = 0.2002092498606682
# contributions:
# measured_0.0_0.25 0.8000000000285048
# measured_0.0_0.3 0.19999999983548697
#
# beta = 0.27 result = 0.20571830395172191
# contributions:
# measured_0.0_0.25 0.6000000001144887
# measured_0.0_0.3 0.3999999996512885
#
# beta = 0.28 result = 0.21122735808444296
# contributions:
# measured_0.0_0.25 0.39999999946329695
# measured_0.0_0.3 0.599999999325457
#
# beta = 0.29 result = 0.21673641214550335
# contributions:
# measured_0.0_0.25 0.1999999998184216
# measured_0.0_0.3 0.7999999996010476
#
# beta = 0.3 result = 0.22224546620854121
# contributions:
# measured_0.0_0.3 0.9999999998958821
#
# beta = 0.31 result = 0.22712453929288692
# contributions:
# measured_0.0_0.3 0.7999999995984044
# measured_0.0_0.35 0.20000000014095812
#
# beta = 0.32 result = 0.2320036122843377
# contributions:
# measured_0.0_0.3 0.5999999999919462
# measured_0.0_0.35 0.40000000000075137
#
# beta = 0.33 result = 0.2368826853474081
# contributions:
# measured_0.0_0.3 0.399999999905154
# measured_0.0_0.35 0.5999999995875965
#
# beta = 0.34 result = 0.24176175837551456
# contributions:
# measured_0.0_0.3 0.19999999964177245
# measured_0.0_0.35 0.8000000001167532
#
# beta = 0.35000000000000003 result = 0.24664083142179882
# contributions:
# measured_0.0_0.35 0.9999999996968775
#
# beta = 0.36 result = 0.2509382688080885
# contributions:
# measured_0.0_0.35 0.7999999999707292
# measured_0.0_0.4 0.19999999996358717
#
# beta = 0.37 result = 0.2552357062113337
# contributions:
# measured_0.0_0.35 0.5999999999068268
# measured_0.0_0.4 0.4000000000274024
#
# beta = 0.38 result = 0.25953314361823365
# contributions:
# measured_0.0_0.35 0.39999999986679735
# measured_0.0_0.4 0.6000000000004837
#
# beta = 0.39 result = 0.2638305810231554
# contributions:
# measured_0.0_0.35 0.1999999999716873
# measured_0.0_0.4 0.7999999998185161
#
# beta = 0.4 result = 0.26812801841833855
# contributions:
# measured_0.0_0.4 0.99999999994985
#
# beta = 0.41000000000000003 result = 0.27188894838711547
# contributions:
# measured_0.0_0.4 0.7999999999362415
# measured_0.0_0.45 0.19999999987162548
#
# beta = 0.42 result = 0.2756498783416971
# contributions:
# measured_0.0_0.4 0.5999999999951127
# measured_0.0_0.45 0.399999999980956
#
# beta = 0.43 result = 0.2794108083375568
# contributions:
# measured_0.0_0.4 0.39999999972685807
# measured_0.0_0.45 0.5999999996558271
#
# beta = 0.44 result = 0.2831717382808193
# contributions:
# measured_0.0_0.4 0.1999999997435477
# measured_0.0_0.45 0.8000000000617641
#
# beta = 0.45 result = 0.28693266823906993
# contributions:
# measured_0.0_0.45 0.9999999998187662
#
# beta = 0.46 result = 0.29019920057220777
# contributions:
# measured_0.0_0.45 0.7999999999188626
# measured_0.0_0.5 0.19999999944075736
#
# beta = 0.47000000000000003 result = 0.2934657328811013
# contributions:
# measured_0.0_0.45 0.599999999985987
# measured_0.0_0.5 0.3999999999974681
#
# beta = 0.48 result = 0.2967322652239619
# contributions:
# measured_0.0_0.45 0.40000000026142113
# measured_0.0_0.5 0.5999999993443977
#
# beta = 0.49 result = 0.2999987975338028
# contributions:
# measured_0.0_0.45 0.19999999996454357
# measured_0.0_0.5 0.8000000000024734
#
# beta = 0.5 result = 0.30326532985709287
# contributions:
# measured_0.0_0.5 0.9999999999735049
#
# beta = 0.51 result = 0.3060767430449989
# contributions:
# measured_0.0_0.5 0.7999999999774564
# measured_0.0_0.55 0.19999999919487982
#
# beta = 0.52 result = 0.3088881561979785
# contributions:
# measured_0.0_0.5 0.599999999988698
# measured_0.0_0.55 0.399999999995368
#
# beta = 0.53 result = 0.3116995693684082
# contributions:
# measured_0.0_0.5 0.39999999999483926
# measured_0.0_0.55 0.5999999999954688
#
# beta = 0.54 result = 0.31451098254204607
# contributions:
# measured_0.0_0.5 0.2000000000298268
# measured_0.0_0.55 0.7999999998545418
#
# beta = 0.55 result = 0.31732239570976173
# contributions:
# measured_0.0_0.55 0.9999999999728113
#
# beta = 0.56 result = 0.3197153129200309
# contributions:
# measured_0.0_0.55 0.8000000007502729
# measured_0.0_0.6 0.199999998164762
#
# beta = 0.5700000000000001 result = 0.32210823010528705
# contributions:
# measured_0.0_0.55 0.6000000003370611
# measured_0.0_0.6 0.39999999902678124
#
# beta = 0.58 result = 0.3245011472876636
# contributions:
# measured_0.0_0.55 0.40000000022837645
# measured_0.0_0.6 0.5999999993283471
#
# beta = 0.59 result = 0.32689406446761426
# contributions:
# measured_0.0_0.55 0.19999999999391907
# measured_0.0_0.6 0.7999999999946694
#
# beta = 0.6 result = 0.32928698166414927
# contributions:
# measured_0.0_0.6 0.9999999996736952
#
# beta = 0.61 result = 0.33129553631186703
# contributions:
# measured_0.0_0.6 0.8000000004912666
# measured_0.0_0.65 0.19999999908547744
#
# beta = 0.62 result = 0.3333040909616658
# contributions:
# measured_0.0_0.6 0.6000000003479145
# measured_0.0_0.65 0.39999999913792744
#
# beta = 0.63 result = 0.33531264560011925
# contributions:
# measured_0.0_0.6 0.4000000000258525
# measured_0.0_0.65 0.5999999999405409
#
# beta = 0.64 result = 0.3373212002481782
# contributions:
# measured_0.0_0.6 0.1999999999973157
# measured_0.0_0.65 0.7999999999596508
#
# beta = 0.65 result = 0.33932975489570355
# contributions:
# measured_0.0_0.65 0.9999999998015995
#
# beta = 0.66 result = 0.3410226663555887
# contributions:
# local_search_1 0.005292472336077744
# local_search_2 0.0012753240178509878
# measured_0.0_0.65 0.8394067779490124
# measured_0.05_0.7 0.15402542528990973
#
# beta = 0.67 result = 0.3427155778204115
# contributions:
# local_search_1 0.010584944658910135
# local_search_2 0.0025506480324411908
# measured_0.0_0.65 0.6788135558677101
# measured_0.05_0.7 0.3080508497798056
#
# beta = 0.68 result = 0.3444084892915607
# contributions:
# local_search_1 0.015877416949533752
# local_search_2 0.0038259720386476137
# measured_0.0_0.65 0.51822033401196
# measured_0.05_0.7 0.4620762713534533
#
# beta = 0.6900000000000001 result = 0.3461014007435422
# contributions:
# local_search_1 0.021169889258656996
# local_search_2 0.005101296050641368
# measured_0.0_0.65 0.3576271117664205
# measured_0.05_0.7 0.6161016976300304
#
# beta = 0.7000000000000001 result = 0.3477943121862802
# contributions:
# local_search_1 0.02646236166540602
# local_search_2 0.006376620087219703
# measured_0.0_0.65 0.1970338905334172
# measured_0.05_0.7 0.7701271275980126
#
# beta = 0.71 result = 0.3494872236439947
# contributions:
# local_search_1 0.031754833996597794
# local_search_2 0.007651944104306983
# measured_0.0_0.65 0.03644066858227263
# measured_0.05_0.7 0.9241525532284832
#
# beta = 0.72 result = 0.3510685110599404
# contributions:
# local_search_1 0.037160364104459734
# local_search_2 0.008730817528107502
# measured_0.05_0.7 0.8294559081076908
# measured_0.1_0.75 0.12465291019291398
#
# beta = 0.73 result = 0.35261703511938197
# contributions:
# local_search_1 0.042599078396726206
# local_search_2 0.009752029705736102
# measured_0.05_0.7 0.6617555402015837
# measured_0.1_0.75 0.28589335126885534
#
# beta = 0.74 result = 0.35416555917533016
# contributions:
# local_search_1 0.0480377926842931
# local_search_2 0.010773241882603856
# measured_0.05_0.7 0.49405517261610027
# measured_0.1_0.75 0.44713379255889707
#
# beta = 0.75 result = 0.3557140832330521
# contributions:
# local_search_1 0.05347650697360251
# local_search_2 0.01179445405994445
# measured_0.05_0.7 0.3263548051981259
# measured_0.1_0.75 0.6083742335440594
#
# beta = 0.76 result = 0.3572626072916637
# contributions:
# local_search_1 0.05891522126400491
# local_search_2 0.012815666237368082
# measured_0.05_0.7 0.1586544373308944
# measured_0.1_0.75 0.7696146745786497
#
# beta = 0.77 result = 0.3588035797925884
# contributions:
# local_search_1 0.06436082768960814
# local_search_2 0.013823772149434517
# measured_0.1_0.75 0.9127383983925296
# measured_0.15_0.8 0.009076999865490773
#
# beta = 0.78 result = 0.3602121072215743
# contributions:
# local_search_1 0.06992731350901568
# local_search_2 0.014602010301241688
# measured_0.1_0.75 0.7381172943152726
# measured_0.15_0.8 0.17735338041473356
#
# beta = 0.79 result = 0.36162063464773336
# contributions:
# local_search_1 0.07549379931463827
# local_search_2 0.015380248448940578
# measured_0.1_0.75 0.5634961908356703
# measured_0.15_0.8 0.34562976061212086
#
# beta = 0.8 result = 0.3630291620741332
# contributions:
# local_search_1 0.08106028512283524
# local_search_2 0.016158486596712648
# measured_0.1_0.75 0.38887508684313454
# measured_0.15_0.8 0.5139061413907917
#
# beta = 0.81 result = 0.36443768951593936
# contributions:
# local_search_1 0.08662677097032559
# local_search_2 0.016936724758301692
# measured_0.1_0.75 0.2142539814904487
# measured_0.15_0.8 0.6821825200345265
#
# beta = 0.8200000000000001 result = 0.36584621693576463
# contributions:
# local_search_1 0.09219325675587199
# local_search_2 0.017714962898974663
# measured_0.1_0.75 0.03963287856018779
# measured_0.15_0.8 0.8504589015128643
#
# beta = 0.8300000000000001 result = 0.36715022697698524
# contributions:
# local_search_1 0.09784410211776168
# local_search_2 0.01831448639184743
# measured_0.15_0.8 0.7484757652591112
# measured_0.2_0.85 0.1353656458983654
#
# beta = 0.84 result = 0.3684235504533486
# contributions:
# local_search_1 0.10351971564842098
# local_search_2 0.01886153881553896
# measured_0.15_0.8 0.567143763344078
# measured_0.2_0.85 0.31047498206290386
#
# beta = 0.85 result = 0.3696968739301751
# contributions:
# local_search_1 0.10919532918337665
# local_search_2 0.019408591240752497
# measured_0.15_0.8 0.38581176113390125
# measured_0.2_0.85 0.4855843182424134
#
# beta = 0.86 result = 0.3709701974074154
# contributions:
# local_search_1 0.11487094271788337
# local_search_2 0.019955643665878056
# measured_0.15_0.8 0.2044797589477858
# measured_0.2_0.85 0.6606936543190136
#
# beta = 0.87 result = 0.3722435208838758
# contributions:
# local_search_1 0.12054655624744705
# local_search_2 0.02050269608914166
# measured_0.15_0.8 0.023147756963818246
# measured_0.2_0.85 0.8358029906200969
#
# beta = 0.88 result = 0.3734033863395557
# contributions:
# local_search_1 0.12630110813877582
# local_search_2 0.020858819598385737
# measured_0.2_0.85 0.6943198525352685
# measured_0.25_0.9 0.15852021492253393
#
# beta = 0.89 result = 0.3745466489944038
# contributions:
# local_search_1 0.13206721134481914
# local_search_2 0.021187003655568883
# measured_0.2_0.85 0.5065084277234532
# measured_0.25_0.9 0.340237352655626
#
# beta = 0.9 result = 0.3756899116458743
# contributions:
# local_search_1 0.13783331455958395
# local_search_2 0.02151518771400404
# measured_0.2_0.85 0.31869700307392274
# measured_0.25_0.9 0.5219544905733383
#
# beta = 0.91 result = 0.37683317430898783
# contributions:
# local_search_1 0.14359941791036504
# local_search_2 0.021843371824285744
# measured_0.2_0.85 0.13088557517538904
# measured_0.25_0.9 0.7036716234969641
#
# beta = 0.92 result = 0.37793866438731866
# contributions:
# local_search_1 0.14938735256545754
# local_search_2 0.022109073405427417
# measured_0.25_0.9 0.7714964255337784
# measured_0.3_0.95 0.05700714773701671
#
# beta = 0.93 result = 0.37895730668650124
# contributions:
# local_search_1 0.15522548339258357
# local_search_2 0.022231113688602838
# measured_0.25_0.9 0.5774565969196633
# measured_0.3_0.95 0.24508680583695178
#
# beta = 0.9400000000000001 result = 0.37997594898707543
# contributions:
# local_search_1 0.16106361425212476
# local_search_2 0.022353153984236002
# measured_0.25_0.9 0.3834167672256226
# measured_0.3_0.95 0.43316646344016146
#
# beta = 0.9500000000000001 result = 0.38099459128649976
# contributions:
# local_search_1 0.16690174508375677
# local_search_2 0.022475194269251212
# measured_0.25_0.9 0.18937693910350714
# measured_0.3_0.95 0.6212461208602055
#
# beta = 0.96 result = 0.38201037546935535
# contributions:
# local_search_1 0.17274117118919718
# local_search_2 0.02259259347140399
# measured_0.3_0.95 0.7999999998783087
# measured_0.35_1.0 0.0046662347841629264
#
# beta = 0.97 result = 0.3829100811146856
# contributions:
# local_search_1 0.17863320276562045
# local_search_2 0.02252150126207237
# measured_0.3_0.95 0.5999999993810969
# measured_0.35_1.0 0.19884529529743156
#
# beta = 0.98 result = 0.383809786762012
# contributions:
# local_search_1 0.18452523438873158
# local_search_2 0.022450409071313293
# measured_0.3_0.95 0.3999999971326488
# measured_0.35_1.0 0.3930243553845332
#
# beta = 0.99 result = 0.3847094924051175
# contributions:
# local_search_1 0.19041726590811456
# local_search_2 0.022379316840104226
# measured_0.3_0.95 0.19999999943753138
# measured_0.35_1.0 0.5872034157851307
#
# beta = 1.0 result = 0.3856091980608543
# contributions:
# local_search_1 0.19630929754555446
# local_search_2 0.022308224670060904
# measured_0.35_1.0 0.7813824706497587
# [1.0180590221663363e-11,
#  0.009512294334414428,
#  0.019024588585388715,
#  0.028536882746117678,
#  0.03804917704862066,
#  0.047561471230423084,
#  0.05614592539364061,
#  0.06473037947879183,
#  0.07331483359597894,
#  0.08189928769216523,
#  0.09048374180975695,
#  0.09820823278175068,
#  0.10593272371064946,
#  0.11365721460686672,
#  0.12138170553611831,
#  0.12910619651169156,
#  0.13603418729582684,
#  0.1429621781285223,
#  0.1498901690474302,
#  0.15681815984555666,
#  0.16374615061955003,
#  0.16993695971503958,
#  0.17612776869664612,
#  0.18231857771072768,
#  0.18850938682347984,
#  0.1947001957951922,
#  0.2002092498606682,
#  0.20571830395172191,
#  0.21122735808444296,
#  0.21673641214550335,
#  0.22224546620854121,
#  0.22712453929288692,
#  0.2320036122843377,
#  0.2368826853474081,
#  0.24176175837551456,
#  0.24664083142179882,
#  0.2509382688080885,
#  0.2552357062113337,
#  0.25953314361823365,
#  0.2638305810231554,
#  0.26812801841833855,
#  0.27188894838711547,
#  0.2756498783416971,
#  0.2794108083375568,
#  0.2831717382808193,
#  0.28693266823906993,
#  0.29019920057220777,
#  0.2934657328811013,
#  0.2967322652239619,
#  0.2999987975338028,
#  0.30326532985709287,
#  0.3060767430449989,
#  0.3088881561979785,
#  0.3116995693684082,
#  0.31451098254204607,
#  0.31732239570976173,
#  0.3197153129200309,
#  0.32210823010528705,
#  0.3245011472876636,
#  0.32689406446761426,
#  0.32928698166414927,
#  0.33129553631186703,
#  0.3333040909616658,
#  0.33531264560011925,
#  0.3373212002481782,
#  0.33932975489570355,
#  0.3410226663555887,
#  0.3427155778204115,
#  0.3444084892915607,
#  0.3461014007435422,
#  0.3477943121862802,
#  0.3494872236439947,
#  0.3510685110599404,
#  0.35261703511938197,
#  0.35416555917533016,
#  0.3557140832330521,
#  0.3572626072916637,
#  0.3588035797925884,
#  0.3602121072215743,
#  0.36162063464773336,
#  0.3630291620741332,
#  0.36443768951593936,
#  0.36584621693576463,
#  0.36715022697698524,
#  0.3684235504533486,
#  0.3696968739301751,
#  0.3709701974074154,
#  0.3722435208838758,
#  0.3734033863395557,
#  0.3745466489944038,
#  0.3756899116458743,
#  0.37683317430898783,
#  0.37793866438731866,
#  0.37895730668650124,
#  0.37997594898707543,
#  0.38099459128649976,
#  0.38201037546935535,
#  0.3829100811146856,
#  0.383809786762012,
#  0.3847094924051175,
#  0.3856091980608543]

# %%
# check that USM and CSM essentially the same
max_dif = 0
for i in range(101):
    max_dif = max(max_dif, abs(ell_neg_usm[i] - ell_neg_csm[i]))
print(max_dif)
# Out:
# 6.80657332580159e-10

# %% [markdown]
# ## Theorem 6.5 ($\ell \ge 0$), Section 6 Table 3

# %%
ell_neg_usm_pairs = list(zip(np.linspace(0, 1.4, 141), ell_neg_usm))
ell_neg_usm_pairs
# Out:
# [(0.0, 1.6935812991431703e-10),
#  (0.01, 0.009512294693261026),
#  (0.02, 0.019024588505687858),
#  (0.03, 0.02853688342677501),
#  (0.04, 0.038049177237314394),
#  (0.05, 0.04756147126436101),
#  (0.06, 0.056145925350583784),
#  (0.07, 0.06473037976343975),
#  (0.08, 0.07331483386810714),
#  (0.09, 0.08189928769484933),
#  (0.1, 0.0904837419838457),
#  (0.11, 0.09820823273992606),
#  (0.12, 0.10593272368803336),
#  (0.13, 0.11365721465105828),
#  (0.14, 0.12138170558141603),
#  (0.15, 0.12910619648199806),
#  (0.16, 0.1360341873083371),
#  (0.17, 0.1429621781339049),
#  (0.18, 0.14989016906481892),
#  (0.19, 0.15681815980361258),
#  (0.2, 0.1637461506586881),
#  (0.21, 0.16993695966927913),
#  (0.22, 0.1761277687004397),
#  (0.23, 0.1823185777101439),
#  (0.24, 0.18850938685300678),
#  (0.25, 0.19470019585273843),
#  (0.26, 0.20020924987436964),
#  (0.27, 0.20571830395563243),
#  (0.28, 0.2112273580348474),
#  (0.29, 0.2167364121618734),
#  (0.3, 0.22224546622123179),
#  (0.31, 0.2271245392461987),
#  (0.32, 0.2320036124748374),
#  (0.33, 0.23688268532676474),
#  (0.34, 0.24176175845216308),
#  (0.35000000000000003, 0.24664083140494636),
#  (0.36, 0.2509382689011808),
#  (0.37, 0.2552357062459843),
#  (0.38, 0.2595331436336315),
#  (0.39, 0.2638305811632357),
#  (0.4, 0.2681280184367834),
#  (0.41000000000000003, 0.27188894837949296),
#  (0.42, 0.2756498783924005),
#  (0.43, 0.2794108083234606),
#  (0.44, 0.2831717382941946),
#  (0.45, 0.28693266823204266),
#  (0.46, 0.29019920068532573),
#  (0.47000000000000003, 0.29346573295745676),
#  (0.48, 0.29673226522186485),
#  (0.49, 0.29999879755713516),
#  (0.5, 0.3032653299208483),
#  (0.51, 0.3060767430296111),
#  (0.52, 0.3088881562781987),
#  (0.53, 0.311699569369419),
#  (0.54, 0.3145109825466697),
#  (0.55, 0.3173223957105257),
#  (0.56, 0.3197153129229596),
#  (0.5700000000000001, 0.32210823010502093),
#  (0.58, 0.32450114727983614),
#  (0.59, 0.32689406446800884),
#  (0.6, 0.329286981661829),
#  (0.61, 0.33129553632095593),
#  (0.62, 0.3333040909529538),
#  (0.63, 0.33531264560470003),
#  (0.64, 0.33732120028160956),
#  (0.65, 0.33932975492468903),
#  (0.66, 0.34102266637814677),
#  (0.67, 0.34271557781897444),
#  (0.68, 0.34440848927925943),
#  (0.6900000000000001, 0.3461014007367732),
#  (0.7000000000000001, 0.34779431219738954),
#  (0.71, 0.34948722364421614),
#  (0.72, 0.35106851106610054),
#  (0.73, 0.3526170351336859),
#  (0.74, 0.3541655592152732),
#  (0.75, 0.35571408323505443),
#  (0.76, 0.3572626072914963),
#  (0.77, 0.3588035797848804),
#  (0.78, 0.3602121072145713),
#  (0.79, 0.3616206346450883),
#  (0.8, 0.36302916207432995),
#  (0.81, 0.36443768950571875),
#  (0.8200000000000001, 0.3658462169347735),
#  (0.8300000000000001, 0.3671502269855766),
#  (0.84, 0.36842355047435016),
#  (0.85, 0.3696968739571791),
#  (0.86, 0.3709701974074439),
#  (0.87, 0.3722435208976867),
#  (0.88, 0.37340338635045134),
#  (0.89, 0.3745466489892939),
#  (0.9, 0.37568991163880067),
#  (0.91, 0.3768331742952566),
#  (0.92, 0.3779386644080668),
#  (0.93, 0.3789573066890315),
#  (0.9400000000000001, 0.37997594898677783),
#  (0.9500000000000001, 0.3809945912981977),
#  (0.96, 0.38201037547110306),
#  (0.97, 0.3829100811162015),
#  (0.98, 0.3838097867591898),
#  (0.99, 0.38470949241933056),
#  (1.0, 0.3856091980491218),
#  (1.01, 0.38639583971885644),
#  (1.02, 0.3871824813854263),
#  (1.03, 0.3879691230523858),
#  (1.04, 0.38873425409779355),
#  (1.05, 0.3894138398450444),
#  (1.06, 0.39009342558942406),
#  (1.07, 0.3907730113349987),
#  (1.08, 0.3913919245585856),
#  (1.09, 0.3919705457054491),
#  (1.1, 0.39254916681985663),
#  (1.11, 0.39311094342256914),
#  (1.12, 0.39359472462145384),
#  (1.1300000000000001, 0.3940785058185787),
#  (1.1400000000000001, 0.39456228701605456),
#  (1.1500000000000001, 0.39496518983952317),
#  (1.16, 0.3953602421945075),
#  (1.17, 0.39575529452505287),
#  (1.18, 0.3960853894851159),
#  (1.19, 0.39639776699889806),
#  (1.2, 0.39671014451943315),
#  (1.21, 0.3969622781007628),
#  (1.22, 0.39719793823074595),
#  (1.23, 0.3974335983635483),
#  (1.24, 0.3976056559854312),
#  (1.25, 0.39777042436931354),
#  (1.26, 0.3979280246359689),
#  (1.27, 0.39802756432056235),
#  (1.28, 0.39812710400994794),
#  (1.29, 0.39820101596527774),
#  (1.3, 0.39820101594947527),
#  (1.31, 0.39820101594853197),
#  (1.32, 0.39820101594908114),
#  (1.33, 0.3982010159629967),
#  (1.34, 0.398201015959116),
#  (1.35, 0.3982010159504843),
#  (1.36, 0.39820101594726776),
#  (1.37, 0.3982010159474121),
#  (1.3800000000000001, 0.398201015953414),
#  (1.3900000000000001, 0.39820101594714974),
#  (1.4, 0.3982010159473649)]

# %%
def thm_ell_pos_usm(betas: Iterable[float]) -> List[float]:
    linear_combs = []
    labels = []
    
    def add_linear_comb(l: list, label: str):
        assert len(l) == 3
        linear_combs.append(l)
        labels.append(label)
    
    for beta, alpha in ell_neg_usm_pairs:
        add_linear_comb([alpha, beta, 1 - beta], f"ell_neg_usm_{r4(beta)}_{alpha}")
    
    for r in np.linspace(1, 2, 1001):
        add_linear_comb([2 / (r+1/r)**2, 2 / (r+1/r)**2, (r**2)/(r+1/r)**2], f"double_greedy_{r}")
    
    weights = cp.Variable(len(linear_combs), nonneg=True)
    sum_vars = []
    for i in range(3):
        sum_var = 0
        for j, linear_comb in enumerate(linear_combs):
            sum_var += weights[j] * linear_comb[i]
        sum_vars.append(sum_var)

    results = []
    for beta in betas:
        constraints = [sum(weights) == 1, sum_vars[1] + sum_vars[2] >= beta, sum_vars[2] >= 0]
        prob = cp.Problem(cp.Maximize(sum_vars[0]), constraints)
        result = prob.solve()
        print("beta =", beta, "result =", result)
        print("contributions")
        for i in range(len(linear_combs)):
            if weights[i].value > utils.EPS:
                print(labels[i], weights[i].value)
        print()
        results.append(result)
    
    return results    

results_ell_pos_usm = thm_ell_pos_usm(np.linspace(0.85, 1, 4))
for r in results_ell_pos_usm:
    print(round(r, 4))
# Out:
# beta = 0.85 result = 0.47489513944380174
# contributions
# ell_neg_usm_1.29_0.39820101596527774 0.00476548901743604
# ell_neg_usm_1.3_0.39820101594947527 0.0045513613190747365
# ell_neg_usm_1.31_0.39820101594853197 0.0045323219900557
# ell_neg_usm_1.32_0.39820101594908114 0.004532181603033886
# ell_neg_usm_1.33_0.3982010159629967 0.004706561188109847
# ell_neg_usm_1.34_0.398201015959116 0.004647555953825672
# ell_neg_usm_1.35_0.3982010159504843 0.004527523847461855
# ell_neg_usm_1.36_0.39820101594726776 0.0044785062903116325
# ell_neg_usm_1.37_0.3982010159474121 0.004472230710883152
# ell_neg_usm_1.38_0.398201015953414 0.0045409081878133965
# ell_neg_usm_1.39_0.39820101594714974 0.004452103988156331
# ell_neg_usm_1.4_0.3982010159473649 0.004446152410808437
# double_greedy_1.229 0.9453466333399626
#
# beta = 0.9 result = 0.44933043161037867
# contributions
# ell_neg_usm_1.29_0.39820101596527774 0.03202762567412679
# ell_neg_usm_1.3_0.39820101594947527 0.03137351394912482
# ell_neg_usm_1.31_0.39820101594853197 0.031187429825047335
# ell_neg_usm_1.32_0.39820101594908114 0.031052475160400522
# ell_neg_usm_1.33_0.3982010159629967 0.03133753540651482
# ell_neg_usm_1.34_0.398201015959116 0.03107321346141889
# ell_neg_usm_1.35_0.3982010159504843 0.03066539725175532
# ell_neg_usm_1.36_0.39820101594726776 0.03042969888165253
# ell_neg_usm_1.37_0.3982010159474121 0.030301812698860044
# ell_neg_usm_1.38_0.398201015953414 0.030358866269715293
# ell_neg_usm_1.39_0.39820101594714974 0.03003867024925253
# ell_neg_usm_1.4_0.3982010159473649 0.029922359612933706
# double_greedy_1.229 0.6302313630292412
#
# beta = 0.95 result = 0.4225756066991291
# contributions
# ell_neg_usm_1.21_0.3969622781007628 0.6391209530446421
# ell_neg_usm_1.22_0.39719793823074595 0.005695023155170856
# ell_neg_usm_1.23_0.3974335983635483 0.003734323621172255
# double_greedy_1.2850000000000001 0.35144949610118076
#
# beta = 1.0 result = 0.38560919804963456
# contributions
# ell_neg_usm_1.0_0.3856091980491218 0.9999999999233742
#
# 0.4749
# 0.4493
# 0.4226
# 0.3856

# %% [markdown]
# ## Theorem 7.1 (RegularizedCSM $\ell \ge 0$)

# %%
def thm_ell_pos(betas: Iterable[float]) -> List[float]:
    keys = ['f_OPT', 'f_z_and_OPT', 'f_z_or_OPT', 'L_OPT_backslash_z', 'L_OPT_and_z']
    linear_combs = []
    labels = []
    def add_linear_comb(d: Dict, label: str):
        val = [0] * len(keys)
        for k, v in d.items():
            val[keys.index(k)] = v
        linear_combs.append(val)
        labels.append(label)
    # (0, 0, 0, 1, 1)
    add_linear_comb({'L_OPT_backslash_z': 1, 'L_OPT_and_z': 1}, "trivial")
    # (0, 0.5, 0.5, 0.5, 1.0)
    add_linear_comb({'f_z_and_OPT': 0.5, 'f_z_or_OPT': 0.5, 'L_OPT_backslash_z': 0.5, 'L_OPT_and_z': 1.0}, "local_search_1")
    # (0, 1, 0, 0, 1)
    add_linear_comb({'f_z_and_OPT': 1.0, 'L_OPT_and_z': 1.0}, "local_search_2")
    # for t_f in np.linspace(0, 1, 41):
    t_f = 1
    for t_s in np.linspace(0, 1, 101):
        if t_s <= t_f:
            add_linear_comb(
                {
                    'f_OPT': exp(t_s-t_f) + t_f * exp(t_s-t_f) - t_s * exp(t_s-t_f) - exp(-t_f),
                    'f_z_and_OPT': -exp(t_s-t_f) + exp(-t_f),
                    'f_z_or_OPT': -exp(t_s-t_f) - t_f * exp(t_s-t_f) + t_s * exp(t_s-t_f) + exp(-t_f) + t_f * exp(-t_f),
                    'L_OPT_backslash_z': 1-exp(-t_f),
                    'L_OPT_and_z': 1-exp(-t_f+t_s),
                }, 
                f'measured_{t_s}_{t_f}'
            )
    
    weights = cp.Variable(len(linear_combs), nonneg=True)
    sum_vars = []
    for j in range(len(keys)):
        sum_var = 0
        for i in range(len(linear_combs)):
            sum_var += linear_combs[i][j] * weights[i]
        sum_vars.append(sum_var)
    
    results = []
    for beta in betas:
        constraints = [sum(weights) == 1, sum_vars[1] >= 0, sum_vars[2] >= 0, sum_vars[3] >= beta, sum_vars[4] >= beta]
        prob = cp.Problem(cp.Maximize(sum_vars[0]), constraints)
        result = prob.solve()
        print("beta =", beta, "result =", result)
        print("contributions")
        for i in range(len(linear_combs)):
            if weights[i].value > utils.EPS:
                print(labels[i], weights[i].value)
        print()
        results.append(result)
    
    return results

# %%
thm_ell_pos(np.linspace(0, 1, 101))
# Out:
# beta = 0.0 result = 0.3856708315441379
# contributions
# local_search_1 0.20409835299636284
# local_search_2 0.024938055939882083
# measured_0.37_1 0.77096358544296
#
# beta = 0.01 result = 0.3856708315441489
# contributions
# local_search_1 0.20409835299635198
# local_search_2 0.024938055939880143
# measured_0.37_1 0.7709635854381856
#
# beta = 0.02 result = 0.38567083154415865
# contributions
# local_search_1 0.20409835299634402
# local_search_2 0.024938055939877538
# measured_0.37_1 0.7709635854351609
#
# beta = 0.03 result = 0.38567083154416926
# contributions
# local_search_1 0.2040983529963385
# local_search_2 0.0249380559398733
# measured_0.37_1 0.7709635854339283
#
# beta = 0.04 result = 0.3856708315441797
# contributions
# local_search_1 0.20409835299633639
# local_search_2 0.024938055939868742
# measured_0.37_1 0.7709635854345115
#
# beta = 0.05 result = 0.38567083154419013
# contributions
# local_search_1 0.20409835299633675
# local_search_2 0.024938055939862504
# measured_0.37_1 0.7709635854369458
#
# beta = 0.06 result = 0.38567083154420034
# contributions
# local_search_1 0.2040983529963403
# local_search_2 0.024938055939855413
# measured_0.37_1 0.7709635854412539
#
# beta = 0.07 result = 0.3856708315442106
# contributions
# local_search_1 0.20409835299634643
# local_search_2 0.024938055939846923
# measured_0.37_1 0.770963585447458
#
# beta = 0.08 result = 0.3856708315442204
# contributions
# local_search_1 0.20409835299635556
# local_search_2 0.02493805593983771
# measured_0.37_1 0.7709635854555711
#
# beta = 0.09 result = 0.3856708315442307
# contributions
# local_search_1 0.2040983529963683
# local_search_2 0.024938055939827494
# measured_0.37_1 0.7709635854656056
#
# beta = 0.1 result = 0.3856708315442412
# contributions
# local_search_1 0.20409835299638324
# local_search_2 0.02493805593981554
# measured_0.37_1 0.7709635854775676
#
# beta = 0.11 result = 0.385670831544251
# contributions
# local_search_1 0.2040983529964012
# local_search_2 0.02493805593980297
# measured_0.37_1 0.7709635854914463
#
# beta = 0.12 result = 0.385670831544261
# contributions
# local_search_1 0.2040983529964221
# local_search_2 0.02493805593978884
# measured_0.37_1 0.770963585507237
#
# beta = 0.13 result = 0.3856708315442703
# contributions
# local_search_1 0.20409835299644613
# local_search_2 0.024938055939774238
# measured_0.37_1 0.7709635855249155
#
# beta = 0.14 result = 0.3856708315442803
# contributions
# local_search_1 0.20409835299647267
# local_search_2 0.024938055939757814
# measured_0.37_1 0.7709635855444595
#
# beta = 0.15 result = 0.3856708315442895
# contributions
# local_search_1 0.20409835299650197
# local_search_2 0.024938055939740664
# measured_0.37_1 0.7709635855658296
#
# beta = 0.16 result = 0.38567083154429865
# contributions
# local_search_1 0.20409835299653364
# local_search_2 0.024938055939721968
# measured_0.37_1 0.7709635855889824
#
# beta = 0.17 result = 0.3856708315443073
# contributions
# local_search_1 0.20409835299656764
# local_search_2 0.024938055939702355
# measured_0.37_1 0.7709635856138632
#
# beta = 0.18 result = 0.3856708315443163
# contributions
# local_search_1 0.204098352996604
# local_search_2 0.02493805593968149
# measured_0.37_1 0.7709635856404082
#
# beta = 0.19 result = 0.38567083154432485
# contributions
# local_search_1 0.20409835299664286
# local_search_2 0.02493805593965988
# measured_0.37_1 0.7709635856685486
#
# beta = 0.2 result = 0.3856708315443332
# contributions
# local_search_1 0.2040983529966833
# local_search_2 0.024938055939636845
# measured_0.37_1 0.7709635856982049
#
# beta = 0.21 result = 0.3856708315443409
# contributions
# local_search_1 0.2040983529967253
# local_search_2 0.02493805593961254
# measured_0.37_1 0.770963585729287
#
# beta = 0.22 result = 0.38567083154434983
# contributions
# local_search_1 0.20409835299677082
# local_search_2 0.024938055939586697
# measured_0.37_1 0.7709635857626963
#
# beta = 0.23 result = 0.38567083154436205
# contributions
# local_search_1 0.20409835299682685
# local_search_2 0.024938055939556576
# measured_0.37_1 0.7709635858028593
#
# beta = 0.24 result = 0.3856708315443746
# contributions
# local_search_1 0.20409835299688459
# local_search_2 0.024938055939525354
# measured_0.37_1 0.7709635858445605
#
# beta = 0.25 result = 0.38567083154438725
# contributions
# local_search_1 0.20409835299694348
# local_search_2 0.024938055939492682
# measured_0.37_1 0.77096358588764
#
# beta = 0.26 result = 0.3856708315443989
# contributions
# local_search_1 0.20409835299700393
# local_search_2 0.024938055939459258
# measured_0.37_1 0.7709635859319296
#
# beta = 0.27 result = 0.3856708315444105
# contributions
# local_search_1 0.2040983529970651
# local_search_2 0.024938055939424695
# measured_0.37_1 0.7709635859772536
#
# beta = 0.28 result = 0.38567083154442167
# contributions
# local_search_1 0.20409835299712603
# local_search_2 0.024938055939388665
# measured_0.37_1 0.7709635860234261
#
# beta = 0.29 result = 0.385670831544432
# contributions
# local_search_1 0.20409835299718807
# local_search_2 0.024938055939352492
# measured_0.37_1 0.7709635860702515
#
# beta = 0.3 result = 0.3856708315444423
# contributions
# local_search_1 0.2040983529972496
# local_search_2 0.024938055939315383
# measured_0.37_1 0.7709635861175288
#
# beta = 0.31 result = 0.38567083154445164
# contributions
# local_search_1 0.20409835299731063
# local_search_2 0.024938055939277774
# measured_0.37_1 0.7709635861650437
#
# beta = 0.32 result = 0.3856708315444605
# contributions
# local_search_1 0.20409835299737122
# local_search_2 0.024938055939240075
# measured_0.37_1 0.770963586212575
#
# beta = 0.33 result = 0.3856708315444695
# contributions
# local_search_1 0.20409835299743084
# local_search_2 0.024938055939202078
# measured_0.37_1 0.7709635862598907
#
# beta = 0.34 result = 0.3856708315444785
# contributions
# local_search_1 0.204098352997489
# local_search_2 0.024938055939163803
# measured_0.37_1 0.7709635863067481
#
# beta = 0.35000000000000003 result = 0.3856708315444866
# contributions
# local_search_1 0.2040983529975482
# local_search_2 0.02493805593912518
# measured_0.37_1 0.7709635863543653
#
# beta = 0.36 result = 0.38567083154449305
# contributions
# local_search_1 0.20409835299761267
# local_search_2 0.024938055939084203
# measured_0.37_1 0.7709635864060668
#
# beta = 0.37 result = 0.3856708315444993
# contributions
# local_search_1 0.20409835299767579
# local_search_2 0.0249380559390443
# measured_0.37_1 0.7709635864567171
#
# beta = 0.38 result = 0.3856708315445057
# contributions
# local_search_1 0.2040983529977365
# local_search_2 0.024938055939004628
# measured_0.37_1 0.7709635865059908
#
# beta = 0.39 result = 0.3856708315445123
# contributions
# local_search_1 0.20409835299779489
# local_search_2 0.02493805593896646
# measured_0.37_1 0.7709635865535336
#
# beta = 0.4 result = 0.3856708315445189
# contributions
# local_search_1 0.20409835299785023
# local_search_2 0.024938055938929768
# measured_0.37_1 0.7709635865989622
#
# beta = 0.41000000000000003 result = 0.38567083154452536
# contributions
# local_search_1 0.2040983529979027
# local_search_2 0.024938055938895223
# measured_0.37_1 0.7709635866418588
#
# beta = 0.42 result = 0.3856708315445317
# contributions
# local_search_1 0.20409835299797388
# local_search_2 0.024938055938864365
# measured_0.37_1 0.7709635866927474
#
# beta = 0.43 result = 0.3856708315445377
# contributions
# local_search_1 0.20409835299804288
# local_search_2 0.02493805593883636
# measured_0.37_1 0.7709635867414564
#
# beta = 0.44 result = 0.3856708315445455
# contributions
# local_search_1 0.2040983529981089
# local_search_2 0.024938055938811297
# measured_0.37_1 0.77096358678692
#
# beta = 0.45 result = 0.3856708315445549
# contributions
# local_search_1 0.2040983529981725
# local_search_2 0.024938055938789668
# measured_0.37_1 0.7709635868289045
#
# beta = 0.46 result = 0.3856708315445633
# contributions
# local_search_1 0.20409835299823445
# local_search_2 0.024938055938773348
# measured_0.37_1 0.7709635868672505
#
# beta = 0.47000000000000003 result = 0.3856708315445742
# contributions
# local_search_1 0.20409835299829607
# local_search_2 0.024938055938761316
# measured_0.37_1 0.7709635869019353
#
# beta = 0.48 result = 0.38567083154458554
# contributions
# local_search_1 0.20409835299836057
# local_search_2 0.024938055938756046
# measured_0.37_1 0.7709635869330866
#
# beta = 0.49 result = 0.3856708315445981
# contributions
# local_search_1 0.20409835299843115
# local_search_2 0.024938055938758207
# measured_0.37_1 0.7709635869610345
#
# beta = 0.5 result = 0.3856708315446119
# contributions
# local_search_1 0.20409835299851334
# local_search_2 0.024938055938769372
# measured_0.37_1 0.7709635869862894
#
# beta = 0.51 result = 0.38567083154462695
# contributions
# local_search_1 0.2040983529986146
# local_search_2 0.024938055938790955
# measured_0.37_1 0.7709635870093321
#
# beta = 0.52 result = 0.3856708315446433
# contributions
# local_search_1 0.20409835299874024
# local_search_2 0.024938055938825445
# measured_0.37_1 0.7709635870298019
#
# beta = 0.53 result = 0.38567083154465975
# contributions
# local_search_1 0.20409835299888712
# local_search_2 0.02493805593887384
# measured_0.37_1 0.7709635870438994
#
# beta = 0.54 result = 0.38567083154468107
# contributions
# local_search_1 0.2040983529990139
# local_search_2 0.02493805593893082
# measured_0.37_1 0.7709635870370958
#
# beta = 0.55 result = 0.38567083154471404
# contributions
# local_search_1 0.20409835299897075
# local_search_2 0.02493805593897544
# measured_0.37_1 0.7709635869667205
#
# beta = 0.56 result = 0.38567083154494963
# contributions
# local_search_1 0.20409835299751036
# local_search_2 0.024938055939216
# measured_0.37_1 0.7709635861246124
#
# beta = 0.5700000000000001 result = 0.3856708315449393
# contributions
# local_search_1 0.20409835299655762
# local_search_2 0.024938055938973486
# measured_0.37_1 0.7709635855257251
#
# beta = 0.58 result = 0.38567083154453385
# contributions
# local_search_1 0.2040983530310033
# local_search_2 0.024938055950466935
# measured_0.37_1 0.7709635811012673
#
# beta = 0.59 result = 0.3856626371501383
# contributions
# local_search_1 0.202363747610254
# local_search_2 0.02433736284903511
# measured_0.36_1 0.3495973747992477
# measured_0.37_1 0.4237015118118655
#
# beta = 0.6 result = 0.3847951883276163
# contributions
# local_search_1 0.17036928223365774
# local_search_2 0.015204811674355952
# measured_0.28_1 0.08335565478330158
# measured_0.29_1 0.7310702490251028
#
# beta = 0.61 result = 0.3822028297259073
# contributions
# local_search_1 0.13012211978688976
# local_search_2 0.0077971702978788335
# measured_0.2_1 0.2769907021901091
# measured_0.21_1 0.5850899942375575
#
# beta = 0.62 result = 0.37744963903826284
# contributions
# local_search_1 0.07953662394791951
# local_search_2 0.00255036101157059
# measured_0.11_1 0.17799966178242213
# measured_0.12_1 0.7399132923181743
#
# beta = 0.63 result = 0.36991191278295316
# contributions
# local_search_1 0.015628734192492943
# local_search_2 8.808723106500688e-05
# measured_0.02_1 0.8285016325347804
# measured_0.03_1 0.155781500613187
#
# beta = 0.64 result = 0.360000000050898
# contributions
# trivial 0.021418542288129557
# measured_0.0_1 0.9785813759623758
#
# beta = 0.65 result = 0.35000000001080767
# contributions
# trivial 0.04860136014432809
# measured_0.0_1 0.9513986248546284
#
# beta = 0.66 result = 0.34000000000292446
# contributions
# trivial 0.07578417838964155
# measured_0.0_1 0.9242158034340748
#
# beta = 0.67 result = 0.33000000000097285
# contributions
# trivial 0.1029669966210362
# measured_0.0_1 0.8970330005820712
#
# beta = 0.68 result = 0.32000000000726936
# contributions
# trivial 0.13014981495572617
# measured_0.0_1 0.8698501776345592
#
# beta = 0.6900000000000001 result = 0.31000000002511674
# contributions
# trivial 0.15733263342200005
# measured_0.0_1 0.8426673341435441
#
# beta = 0.7000000000000001 result = 0.3000000000334334
# contributions
# trivial 0.18451545232131253
# measured_0.0_1 0.8154843241259654
#
# beta = 0.71 result = 0.290000000000898
# contributions
# trivial 0.21169826976287814
# measured_0.0_1 0.7883017267295693
#
# beta = 0.72 result = 0.2800000000008451
# contributions
# trivial 0.23888108804627656
# measured_0.0_1 0.7611189087218709
#
# beta = 0.73 result = 0.27000000003973285
# contributions
# trivial 0.26606390713472816
# measured_0.0_1 0.7339358919078945
#
# beta = 0.74 result = 0.26000000000142454
# contributions
# trivial 0.2932467246210277
# measured_0.0_1 0.7067532714428546
#
# beta = 0.75 result = 0.25000000000223044
# contributions
# trivial 0.3204295429130343
# measured_0.0_1 0.6795704519676133
#
# beta = 0.76 result = 0.240000000002546
# contributions
# trivial 0.3476123611987896
# measured_0.0_1 0.6523876334694646
#
# beta = 0.77 result = 0.2300000000013823
# contributions
# trivial 0.37479517947205193
# measured_0.0_1 0.625204816825962
#
# beta = 0.78 result = 0.2200000000080147
# contributions
# trivial 0.40197799781312515
# measured_0.0_1 0.5980219915211918
#
# beta = 0.79 result = 0.2100000000238391
# contributions
# trivial 0.4291608163167955
# measured_0.0_1 0.5708391296568943
#
# beta = 0.8 result = 0.2000000000101923
# contributions
# trivial 0.45634363441841047
# measured_0.0_1 0.5436563486867892
#
# beta = 0.81 result = 0.19000000000144124
# contributions
# trivial 0.48352645260850025
# measured_0.0_1 0.5164735446069547
#
# beta = 0.8200000000000001 result = 0.18000000000094402
# contributions
# trivial 0.5107092708873132
# measured_0.0_1 0.48929072721365313
#
# beta = 0.8300000000000001 result = 0.17000000002151533
# contributions
# trivial 0.537892089493713
# measured_0.0_1 0.4621078265054666
#
# beta = 0.84 result = 0.1600000000427131
# contributions
# trivial 0.5650749079469471
# measured_0.0_1 0.43492498147627445
#
# beta = 0.85 result = 0.15000000000084637
# contributions
# trivial 0.5922577257392905
# measured_0.0_1 0.407742272713061
#
# beta = 0.86 result = 0.1400000000012841
# contributions
# trivial 0.6194405440265968
# measured_0.0_1 0.3805594541313701
#
# beta = 0.87 result = 0.13000000000170325
# contributions
# trivial 0.6466233623135764
# measured_0.0_1 0.3533766356083056
#
# beta = 0.88 result = 0.12000000000202662
# contributions
# trivial 0.6738061805998506
# measured_0.0_1 0.3261938171685597
#
# beta = 0.89 result = 0.11000000000190854
# contributions
# trivial 0.700988998883818
# measured_0.0_1 0.2990109989615843
#
# beta = 0.9 result = 0.1000000000022838
# contributions
# trivial 0.7281718171883805
# measured_0.0_1 0.2718281736350992
#
# beta = 0.91 result = 0.09000000000641344
# contributions
# trivial 0.7553546355591774
# measured_0.0_1 0.24464532823611934
#
# beta = 0.92 result = 0.080000000006926
# contributions
# trivial 0.7825374538560873
# measured_0.0_1 0.21746250794003333
#
# beta = 0.93 result = 0.07000000000751323
# contributions
# trivial 0.8097202720816788
# measured_0.0_1 0.19027971781004568
#
# beta = 0.9400000000000001 result = 0.06000000000134489
# contributions
# trivial 0.8369030903040848
# measured_0.0_1 0.16309690780847738
#
# beta = 0.9500000000000001 result = 0.05000000000196042
# contributions
# trivial 0.8640859085940436
# measured_0.0_1 0.1359140887673056
#
# beta = 0.96 result = 0.04000000000132442
# contributions
# trivial 0.891268726873468
# measured_0.0_1 0.1087312713071472
#
# beta = 0.97 result = 0.030000000027479573
# contributions
# trivial 0.9184515454442073
# measured_0.0_1 0.08154839994301091
#
# beta = 0.98 result = 0.020000000001982054
# contributions
# trivial 0.9456343634686064
# measured_0.0_1 0.0543656260755576
#
# beta = 0.99 result = 0.010000000001201593
# contributions
# trivial 0.9728171817272803
# measured_0.0_1 0.027182816025967015
#
# beta = 1.0 result = 5.34934743721965e-11
# contributions
# trivial 0.9999999999696763
# [0.3856708315441379,
#  0.3856708315441489,
#  0.38567083154415865,
#  0.38567083154416926,
#  0.3856708315441797,
#  0.38567083154419013,
#  0.38567083154420034,
#  0.3856708315442106,
#  0.3856708315442204,
#  0.3856708315442307,
#  0.3856708315442412,
#  0.385670831544251,
#  0.385670831544261,
#  0.3856708315442703,
#  0.3856708315442803,
#  0.3856708315442895,
#  0.38567083154429865,
#  0.3856708315443073,
#  0.3856708315443163,
#  0.38567083154432485,
#  0.3856708315443332,
#  0.3856708315443409,
#  0.38567083154434983,
#  0.38567083154436205,
#  0.3856708315443746,
#  0.38567083154438725,
#  0.3856708315443989,
#  0.3856708315444105,
#  0.38567083154442167,
#  0.385670831544432,
#  0.3856708315444423,
#  0.38567083154445164,
#  0.3856708315444605,
#  0.3856708315444695,
#  0.3856708315444785,
#  0.3856708315444866,
#  0.38567083154449305,
#  0.3856708315444993,
#  0.3856708315445057,
#  0.3856708315445123,
#  0.3856708315445189,
#  0.38567083154452536,
#  0.3856708315445317,
#  0.3856708315445377,
#  0.3856708315445455,
#  0.3856708315445549,
#  0.3856708315445633,
#  0.3856708315445742,
#  0.38567083154458554,
#  0.3856708315445981,
#  0.3856708315446119,
#  0.38567083154462695,
#  0.3856708315446433,
#  0.38567083154465975,
#  0.38567083154468107,
#  0.38567083154471404,
#  0.38567083154494963,
#  0.3856708315449393,
#  0.38567083154453385,
#  0.3856626371501383,
#  0.3847951883276163,
#  0.3822028297259073,
#  0.37744963903826284,
#  0.36991191278295316,
#  0.360000000050898,
#  0.35000000001080767,
#  0.34000000000292446,
#  0.33000000000097285,
#  0.32000000000726936,
#  0.31000000002511674,
#  0.3000000000334334,
#  0.290000000000898,
#  0.2800000000008451,
#  0.27000000003973285,
#  0.26000000000142454,
#  0.25000000000223044,
#  0.240000000002546,
#  0.2300000000013823,
#  0.2200000000080147,
#  0.2100000000238391,
#  0.2000000000101923,
#  0.19000000000144124,
#  0.18000000000094402,
#  0.17000000002151533,
#  0.1600000000427131,
#  0.15000000000084637,
#  0.1400000000012841,
#  0.13000000000170325,
#  0.12000000000202662,
#  0.11000000000190854,
#  0.1000000000022838,
#  0.09000000000641344,
#  0.080000000006926,
#  0.07000000000751323,
#  0.06000000000134489,
#  0.05000000000196042,
#  0.04000000000132442,
#  0.030000000027479573,
#  0.020000000001982054,
#  0.010000000001201593,
#  5.34934743721965e-11]

# %% [markdown]
# ## Theorem 8.3, Conference Theorem 5 ($\ell$ Unconstrained)

# %%
def thm_ell_pos(betas: Iterable[float]) -> List[float]:
    keys = ['f_OPT', 'f_z_and_OPT', 'f_z_or_OPT', 'L_OPT_backslash_z', 'L_OPT_and_z', 'L_OPT_backslash_z_neg', 'L_OPT_and_z_neg']
    linear_combs = []
    labels = []
    def add_linear_comb(d: Dict, label: str):
        val = [0] * len(keys)
        for k, v in d.items():
            val[keys.index(k)] = v
        linear_combs.append(val)
        labels.append(label)
    # (0, 0, 0, 1, 1)
    add_linear_comb({'L_OPT_backslash_z': 1, 'L_OPT_and_z': 1}, "trivial")
    # (0, 0.5, 0.5, 0.5, 1.0, 1.0, 1.0)
    add_linear_comb({'f_z_and_OPT': 0.5, 'f_z_or_OPT': 0.5, 'L_OPT_backslash_z': 0.5, 'L_OPT_and_z': 1.0, 'L_OPT_backslash_z_neg': 1.0, 'L_OPT_and_z_neg': 1.0}, "local_search_1")
    # (0, 1, 0, 0, 1, 0.0, 1.0)
    add_linear_comb({'f_z_and_OPT': 1.0, 'L_OPT_and_z': 1.0, 'L_OPT_and_z_neg': 1.0}, "local_search_2")
    # for t_f in np.linspace(0, 1, 41):
    for (t_s, t_f) in [(0.205, 0.955)]:
        add_linear_comb(
            {
                'f_OPT': exp(t_s-t_f) + t_f * exp(t_s-t_f) - t_s * exp(t_s-t_f) - exp(-t_f),
                'f_z_and_OPT': -exp(t_s-t_f) + exp(-t_f),
                'f_z_or_OPT': -exp(t_s-t_f) - t_f * exp(t_s-t_f) + t_s * exp(t_s-t_f) + exp(-t_f) + t_f * exp(-t_f),
                'L_OPT_backslash_z': 1-exp(-t_f),
                'L_OPT_and_z': 1-exp(-t_f+t_s),
                'L_OPT_backslash_z_neg': t_f,
                'L_OPT_and_z_neg': t_f-t_s,
            }, 
            f'measured_{t_s}_{t_f}'
        )
    
    weights = cp.Variable(len(linear_combs), nonneg=True)
    sum_vars = []
    for j in range(len(keys)):
        sum_var = 0
        for i in range(len(linear_combs)):
            sum_var += linear_combs[i][j] * weights[i]
        sum_vars.append(sum_var)
    
    results = []
    for beta in betas:
        constraints = [sum(weights) == 1, sum_vars[1] >= 0, sum_vars[2] >= 0, sum_vars[3] >= beta, sum_vars[4] >= beta, sum_vars[5] <= beta, sum_vars[6] <= beta]
        prob = cp.Problem(cp.Maximize(sum_vars[0]), constraints)
        result = prob.solve()
        print("beta =", beta, "result =", result)
        print("contributions")
        for i in range(len(linear_combs)):
            if weights[i].value > utils.EPS:
                print(labels[i], weights[i].value)
        print()
        results.append(result)
    
    return results

thm_ell_pos([0.7])
# Out:
# beta = 0.7 result = 0.2802298156858885
# contributions
# trivial 0.2628936800139511
# local_search_1 0.09429218432600248
# local_search_2 0.008565114011325627
# measured_0.205_0.955 0.6342490216485358
# [0.2802298156858885]

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=6cbc651c-00ab-4e5c-98d9-adde0f700e67' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
